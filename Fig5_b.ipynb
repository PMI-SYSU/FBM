# %%
import numpy as np
epsilons = np.arange(0, 0.8, 0.01)
final_acc_test_MLP = np.load('FBM/data/acc/final_acc_MLP.npy')
final_acc_FBM_009 = np.load('FBM/data/acc/final_acc_FBM_009.npy')
final_acc_FBM_02 = np.load('FBM/data/acc/final_acc_FBM_02.npy')
final_acc_FBM_0375 = np.load('FBM/data/acc/final_acc_FBM_0375.npy')
final_acc_FBM_0465 = np.load('FBM/data/acc/final_acc_FBM_0465.npy')
final_acc_FBM_056 = np.load('FBM/data/acc/final_acc_FBM_056.npy')
final_acc_FBM_08 = np.load('FBM/data/acc/final_acc_FBM_08.npy')
final_acc_FBM_10 = np.load('FBM/data/acc/final_acc_FBM_10.npy')
final_acc_FBM_12 = np.load('FBM/data/acc/final_acc_FBM_12.npy')
mlp_mean=np.average(final_acc_test_MLP, axis=0)
mlp_min=np.min(final_acc_test_MLP, axis=0)
mlp_max=np.max(final_acc_test_MLP, axis=0)

fbm_009_mean=np.average(final_acc_FBM_009, axis=0)
fbm_009_min=np.min(final_acc_FBM_009, axis=0)
fbm_009_max=np.max(final_acc_FBM_009, axis=0)

fbm_02_mean=np.average(final_acc_FBM_02, axis=0)
fbm_02_min=np.min(final_acc_FBM_02, axis=0)
fbm_02_max=np.max(final_acc_FBM_02, axis=0)

fbm_0375_mean=np.average(final_acc_FBM_0375, axis=0)
fbm_0375_min=np.min(final_acc_FBM_0375, axis=0)
fbm_0375_max=np.max(final_acc_FBM_0375, axis=0)

fbm_0465_mean=np.average(final_acc_FBM_0465, axis=0)
fbm_0465_min=np.min(final_acc_FBM_0465, axis=0)
fbm_0465_max=np.max(final_acc_FBM_0465, axis=0)

fbm_056_mean=np.average(final_acc_FBM_056, axis=0)
fbm_056_min=np.min(final_acc_FBM_056, axis=0)
fbm_056_max=np.max(final_acc_FBM_056, axis=0)

fbm_08_mean=np.average(final_acc_FBM_08, axis=0)
fbm_08_min=np.min(final_acc_FBM_08, axis=0)
fbm_08_max=np.max(final_acc_FBM_08, axis=0)


fbm_10_mean=np.average(final_acc_FBM_10, axis=0)
fbm_10_min=np.min(final_acc_FBM_10, axis=0)
fbm_10_max=np.max(final_acc_FBM_10, axis=0)


fbm_12_mean=np.average(final_acc_FBM_12, axis=0)
fbm_12_min=np.min(final_acc_FBM_12, axis=0)
fbm_12_max=np.max(final_acc_FBM_12, axis=0)


#########################
#       画图环节         #
#########################
import matplotlib.pyplot as plt

deep_purple = (0.4, 0.3, 0.7)
xx = epsilons
n = len(epsilons)
inter = 5

fig = plt.figure(figsize=(4,3), dpi=500)
ax2 = fig.add_subplot(111)

ax2.plot(xx[0:n:inter], mlp_mean[0:n:inter], color='#CFB0E8', label = 'MLP',linewidth=1.8,marker='s',markerfacecolor='None',ms=4, linestyle='-')
#ax2.fill_between(xx,mlp_min, mlp_max, color='#A33E18', alpha=0.38)


# colors = ['#7ECEFD', '#FFAA5D', '#91C46C' , deep_purple,'#284907',  '#145AA1']
# colors = plt.get_cmap("Blues")

colors = [
    '#61ace0',  # 渐变色1
    '#4790cb',  # 渐变色2
    '#2d75b5',  # 渐变色3
    '#145AA1',  # 你指定的颜色
#     '#4A90A4',  # 淡青蓝
    '#5FCBCB',
    '#149a6d',
    '#349899',  # 暗青绿
    '#2F8073',  # 深青绿
]


ax2.plot(xx[0:n:inter], fbm_009_mean[0:n:inter],  color='#100150', marker='s',ms=4,linewidth=1.3)
#ax2.fill_between(xx,fbm_009_min, fbm_009_max, color=colors[0], alpha=0.08)

ax2.plot(xx[0:n:inter], fbm_02_mean[0:n:inter],color='#4D028F',marker='s',ms=4,linewidth=1.3)
#ax2.fill_between(xx,fbm_02_min, fbm_02_max, color=colors[1], alpha=0.08)


ax2.plot(xx[0:n:inter], fbm_0375_mean[0:n:inter], color='#B0007F',marker='s',ms=4,linewidth=1.3)
#ax2.fill_between(xx,fbm_0375_min, fbm_0375_max, color=colors[2], alpha=0.08)


ax2.plot(xx[0:n:inter], fbm_0465_mean[0:n:inter],color='#EA2462',marker='s',ms=4,linewidth=1.3)
#ax2.fill_between(xx,fbm_0465_min, fbm_0465_max, color=colors[3], alpha=0.14)

ax2.plot(xx[0:n:inter], fbm_056_mean[0:n:inter], color='#FF7449',marker='s',ms=4,linewidth=1.3)
#ax2.fill_between(xx,fbm_056_min, fbm_056_max, color=colors[4], alpha=0.08)

ax2.plot(xx[0:n:inter], fbm_08_mean[0:n:inter], color='#FFB946', marker='s',ms=4,linewidth=1.3)
#ax2.fill_between(xx,fbm_08_min, fbm_08_max, color=colors[5], alpha=0.08)

ax2.set_xlim(-0.02,0.8)


plt.xlabel(r"$\epsilon$",fontsize=15)
# plt.ylabel("Accuracy (%)",fontsize=15)
plt.ylabel(r'$ACC_{Noise}$', fontsize=15)
plt.yticks([ 0, 20,  40, 60, 80],fontsize=10)
plt.xticks([0.0, 0.2, 0.4, 0.6, 0.8],fontsize=10)
plt.yticks([])  # 去掉y轴

# plt.savefig('WN.png')
plt.show()
